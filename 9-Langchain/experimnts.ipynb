# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
HF_TOKEN=os.getenv('HF_TOKEN1')

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace

llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="conversational",
    max_new_tokens=512,
    temperature=0.7,
)

chat = ChatHuggingFace(llm=llm)

response = chat.invoke("Explain machine learning in simple words.")

print(response.content)
# Out:
# **What is Machine Learning?**
#
# Machine learning is a way that computers can learn and improve on their own, without being explicitly programmed. It's a type of artificial intelligence (AI) that allows computers to make decisions and predictions based on data.
#
# **How Does it Work?**
#
# Imagine you have a lot of data, like pictures of cats and dogs. A machine learning algorithm can look at this data and learn to recognize the differences between cats and dogs. Over time, it gets better and better at making accurate predictions.
#
# Here's a simple example:
#
# 1. **You show the machine learning algorithm many pictures of cats and dogs.**
# 2. **It looks at the pictures and tries to find patterns, like "cats have whiskers" and "dogs have floppy ears."**
# 3. **It uses this information to make predictions: "This picture is a cat" or "This picture is a dog."**
# 4. **As it sees more pictures, it gets better at making accurate predictions.**
#
# **Types of Machine Learning**
#
# There are three main types of machine learning:
#
# 1. **Supervised Learning**: The algorithm is trained on labeled data (e.g., pictures of cats and dogs with labels).
# 2. **Unsupervised Learning**: The algorithm is trained on unlabeled data and tries to find patterns.
# 3. **Reinforcement Learning**: The algorithm learns by trial and error, receiving rewards or penalties for its actions.
#
# **Real-World Applications**
#
# Machine learning is used in many areas, such as:
#
# 1. **Image recognition**: Self-driving cars use machine learning to recognize pedestrians and other obstacles.
# 2. **Speech recognition**: Virtual assistants like Siri and Alexa use machine learning to understand voice commands.
# 3. **Recommendation systems**: Online shopping platforms use machine learning to suggest products based on your browsing history.
#
# In summary, machine learning is a way that computers can learn and improve on their own, by analyzing data and making predictions. It's a powerful tool with many real-world applications.

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("""
Question: {question}

Answer step by step.
""")

# %%
from langchain_core.output_parsers import StrOutputParser
chain = prompt | chat | StrOutputParser()

print(chain.invoke({
    "question": "Who won the cricket World up 2011"
}))
# Out:
# To determine who won the Cricket World Cup in 2011, we can follow these steps:
#
# 1. Identify the year: The year in question is 2011.
# 2. Recall the host country: The 2011 Cricket World Cup was held in India, Sri Lanka, and Bangladesh.
# 3. Determine the winner: The final match of the 2011 Cricket World Cup was played between India and Sri Lanka.
# 4. Identify the winning team: India won the 2011 Cricket World Cup, defeating Sri Lanka in the final match.
#
# So, the answer to the question is:
# India won the Cricket World Cup in 2011.
