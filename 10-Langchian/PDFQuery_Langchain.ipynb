# %%
from langchain_community.vectorstores import Cassandra
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

vectorstore = Cassandra(
    embedding=embeddings,
    keyspace="your_keyspace",
    table_name="your_table",
)

retriever = vectorstore.as_retriever()

docs = retriever.invoke("What is LangChain?")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # LangChain components to use
#       2 from langchain_community.vectorstores import Cassandra
# ----> 3 from langchain.indexes import VectorStoreIndexWrapper
#       4 from langchain_openai import OpenAI
#       5 from langchain.embeddings import OpenAIEmbeddings
#
# ModuleNotFoundError: No module named 'langchain.indexes'
