# %%
from google import genai
import os

client = genai.Client(
    api_key=os.getenv("GOOGLE_API_KEY")
)

for model in client.models.list():
    print(model.name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from google import genai
#       2 import os
#       4 client = genai.Client(
#       5     api_key=os.getenv("GOOGLE_API_KEY")
#       6 )
#
# File d:\Langchain\venv\Lib\site-packages\google\genai\__init__.py:18
#       1 # Copyright 2025 Google LLC
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 #
#      16 """Google Gen AI SDK"""
# ---> 18 from . import interactions
#      19 from . import types
#      20 from . import version
#
# File d:\Langchain\venv\Lib\site-packages\google\genai\interactions.py:23
#      19 from typing import Union
#      21 from typing_extensions import Literal, Required, TypedDict
# ---> 23 from ._gaos.types.interactions import *  # noqa: F401,F403
#      24 from ._gaos.types.interactions import __all__ as _interactions_all
#      25 from ._gaos.models.listagents import ListAgentsRequestParam as AgentListParams
#
# File d:\Langchain\venv\Lib\site-packages\google\genai\_gaos\__init__.py:26
#      17 """Code generated by Speakeasy (https://speakeasy.com). DO NOT EDIT."""
#      19 from ._version import (
#      20     __title__,
#      21     __version__,
#    (...)     24     __user_agent__,
#      25 )
# ---> 26 from .sdk import *
#      27 from .sdkconfiguration import *
#      28 from . import resources
#
# File d:\Langchain\venv\Lib\site-packages\google\genai\_gaos\sdk.py:19
#       1 # Copyright 2026 Google LLC
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     14 #
#      15 # pyformat: disable
#      17 """Code generated by Speakeasy (https://speakeasy.com). DO NOT EDIT."""
# ---> 19 from . import models, types, utils
#      20 from ._hooks import AsyncSDKHooks, SDKHooks, init_async_hooks
#      21 from .basesdk import AsyncBaseSDK, BaseSDK
#
# File d:\Langchain\venv\Lib\site-packages\google\genai\_gaos\types\__init__.py:19
#       1 # Copyright 2026 Google LLC
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     14 #
#      15 # pyformat: disable
#      17 """Code generated by Speakeasy (https://speakeasy.com). DO NOT EDIT."""
# ---> 19 from .basemodel import (
#      20     BaseModel,
#      21     Nullable,
#      22     OptionalNullable,
#      23     UnrecognizedInt,
#      24     UnrecognizedStr,
#      25     UNSET,
#      26     UNSET_SENTINEL,
#      27 )
#      28 from .base64fileinput import Base64EncodedString, Base64FileInput
#      29 from typing import Any, TYPE_CHECKING
#
# File d:\Langchain\venv\Lib\site-packages\google\genai\_gaos\types\basemodel.py:21
#      17 """Code generated by Speakeasy (https://speakeasy.com). DO NOT EDIT."""
#      19 import json
# ---> 21 from pydantic import ConfigDict, model_serializer
#      22 from pydantic import BaseModel as PydanticBaseModel
#      23 from pydantic_core import core_schema, to_jsonable_python
#
# ImportError: cannot import name 'model_serializer' from 'pydantic' (d:\Langchain\venv\Lib\site-packages\pydantic\__init__.cp311-win_amd64.pyd)

# %%
# !pip install google-genai
# Out:
# Collecting google-genai
#   Using cached google_genai-2.9.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in d:\Langchain\venv\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.55.0)
# Collecting httpx<1.0.0,>=0.28.1 (from google-genai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3.0.0,>=2.12.5 (from google-genai)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in d:\Langchain\venv\Lib\site-packages (from google-genai) (2.33.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in d:\Langchain\venv\Lib\site-packages (from google-genai) (8.5.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in d:\Langchain\venv\Lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in d:\Langchain\venv\Lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\Langchain\venv\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in d:\Langchain\venv\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in d:\Langchain\venv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (46.0.5)
# Requirement already satisfied: certifi in d:\Langchain\venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Langchain\venv\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\Langchain\venv\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\Langchain\venv\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\Langchain\venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\Langchain\venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.2)
# Using cached google_genai-2.9.0-py3-none-any.whl (950 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Installing collected packages: pydantic, httpx, google-genai
#
#   Attempting uninstall: pydantic
#
#     Found existing installation: pydantic 1.10.13
#
#    ---------------------------------------- 0/3 [pydantic]
#     Uninstalling pydantic-1.10.13:
#    ---------------------------------------- 0/3 [pydantic]
#       Successfully uninstalled pydantic-1.10.13
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#   Attempting uninstall: httpx
#    ---------------------------------------- 0/3 [pydantic]
#     Found existing installation: httpx 0.27.2
#    ---------------------------------------- 0/3 [pydantic]
#     Uninstalling httpx-0.27.2:
#    ---------------------------------------- 0/3 [pydantic]
#       Successfully uninstalled httpx-0.27.2
#    ---------------------------------------- 0/3 [pydantic]
#    ------------- -------------------------- 1/3 [httpx]
#    ------------- -------------------------- 1/3 [httpx]
#    ------------- -------------------------- 1/3 [httpx]
#    ------------- -------------------------- 1/3 [httpx]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    -------------------------- ------------- 2/3 [google-genai]
#    ---------------------------------------- 3/3 [google-genai]
#
# Successfully installed google-genai-2.9.0 httpx-0.28.1 pydantic-2.13.4
#   WARNING: Failed to remove contents in a temporary directory 'D:\Langchain\venv\Lib\site-packages\~ydantic'.
#   You can safely remove it manually.

# %%
# !pip show pydantic
# Out:
# Name: pydantic
# Version: 2.13.4
# Summary: Data validation using Python type hints
# Home-page: https://github.com/pydantic/pydantic
# Author:
# Author-email: Samuel Colvin <s@muelcolvin.com>, Eric Jolibois <em.jolibois@gmail.com>, Hasan Ramezani <hasan.r67@gmail.com>, Adrian Garcia Badaracco <1755071+adriangb@users.noreply.github.com>, Terrence Dorsey <terry@pydantic.dev>, David Montague <david@pydantic.dev>, Serge Matveenko <lig@countzero.co>, Marcelo Trylesinski <marcelotryle@gmail.com>, Sydney Runkle <sydneymarierunkle@gmail.com>, David Hewitt <mail@davidhewitt.dev>, Alex Hall <alex.mojaki@gmail.com>, Victorien Plot <contact@vctrn.dev>
# License-Expression: MIT
# Location: d:\Langchain\venv\Lib\site-packages
# Requires: annotated-types, pydantic-core, typing-extensions, typing-inspection
# Required-by: chromadb, fastapi, google-genai, google-generativeai, groq, langchain, langchain-core, langserve, langsmith, openai, pydantic-settings

# %%
# !pip install google-genai==1.21.1
# Out:
# Collecting google-genai==1.21.1
#   Downloading google_genai-1.21.1-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from google-genai==1.21.1) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in d:\Langchain\venv\Lib\site-packages (from google-genai==1.21.1) (2.55.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in d:\Langchain\venv\Lib\site-packages (from google-genai==1.21.1) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in d:\Langchain\venv\Lib\site-packages (from google-genai==1.21.1) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in d:\Langchain\venv\Lib\site-packages (from google-genai==1.21.1) (2.33.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in d:\Langchain\venv\Lib\site-packages (from google-genai==1.21.1) (8.5.0)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai==1.21.1)
#   Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in d:\Langchain\venv\Lib\site-packages (from google-genai==1.21.1) (4.15.0)
# Requirement already satisfied: idna>=2.8 in d:\Langchain\venv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai==1.21.1) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai==1.21.1) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai==1.21.1) (46.0.5)
# Requirement already satisfied: certifi in d:\Langchain\venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai==1.21.1) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from httpx<1.0.0,>=0.28.1->google-genai==1.21.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai==1.21.1) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Langchain\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai==1.21.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\Langchain\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai==1.21.1) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\Langchain\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai==1.21.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\Langchain\venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai==1.21.1) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\Langchain\venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai==1.21.1) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-genai==1.21.1) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-genai==1.21.1) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai==1.21.1) (0.6.2)
# Downloading google_genai-1.21.1-py3-none-any.whl (206 kB)
# Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Installing collected packages: websockets, google-genai
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 16.0
#
#     Uninstalling websockets-16.0:
#
#       Successfully uninstalled websockets-16.0
#
#    ---------------------------------------- 0/2 [websockets]
#    ---------------------------------------- 0/2 [websockets]
#    ---------------------------------------- 0/2 [websockets]
#    ---------------------------------------- 0/2 [websockets]
#    ---------------------------------------- 0/2 [websockets]
#    ---------------------------------------- 0/2 [websockets]
#   Attempting uninstall: google-genai
#    ---------------------------------------- 0/2 [websockets]
#    -------------------- ------------------- 1/2 [google-genai]
#     Found existing installation: google-genai 2.9.0
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#     Uninstalling google-genai-2.9.0:
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#       Successfully uninstalled google-genai-2.9.0
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    ---------------------------------------- 2/2 [google-genai]
#
# Successfully installed google-genai-1.21.1 websockets-15.0.1

# %%
import google.genai as genai
import os

client = genai.Client(
    api_key=os.getenv("GOOGLE_API_KEY")
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is Generative AI?"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2416\3045678613.py in ?()
# ----> 1 import google.genai as genai
#       2 import os
#       3
#       4 client = genai.Client(
#
# d:\Langchain\venv\Lib\site-packages\google\genai\__init__.py in ?()
#      15
#      16 """Google Gen AI SDK"""
#      17
#      18 from . import version
# ---> 19 from .client import Client
#      20
#      21
#      22 __version__ = version.__version__
#
# d:\Langchain\venv\Lib\site-packages\google\genai\client.py in ?()
#      18
#      19 import google.auth
#      20 import pydantic
#      21
# ---> 22 from ._api_client import BaseApiClient
#      23 from ._base_url import get_base_url
#      24 from ._replay_api_client import ReplayApiClient
#      25 from .batches import AsyncBatches, Batches
#
# d:\Langchain\venv\Lib\site-packages\google\genai\_api_client.py in ?()
#      53
#      54 from . import _common
#      55 from . import errors
#      56 from . import version
# ---> 57 from .types import HttpOptions
#      58 from .types import HttpOptionsDict
#      59 from .types import HttpOptionsOrDict
#      60 from .types import HttpResponse as SdkHttpResponse
#
# d:\Langchain\venv\Lib\site-packages\google\genai\types.py in ?()
#    3505
#    3506 SpeechConfigUnionDict = Union[SpeechConfigUnion, SpeechConfigDict]
#    3507
#    3508
# -> 3509 class GenerateContentConfig(_common.BaseModel):
#    3510   """Optional model configuration parameters.
#    3511
#    3512   For more information, see `Content generation parameters
#
# d:\Langchain\venv\Lib\site-packages\google\genai\types.py in ?()
#
# AttributeError: module 'pydantic' has no attribute 'field_validator'

# %%
# !pip show pydantic
# !pip showgoogle-genai
# !pip show langchain 
# !pip show langchain-google-genai
# Out:
# Name: pydantic
# Version: 2.13.4
# Summary: Data validation using Python type hints
# Home-page: https://github.com/pydantic/pydantic
# Author:
# Author-email: Samuel Colvin <s@muelcolvin.com>, Eric Jolibois <em.jolibois@gmail.com>, Hasan Ramezani <hasan.r67@gmail.com>, Adrian Garcia Badaracco <1755071+adriangb@users.noreply.github.com>, Terrence Dorsey <terry@pydantic.dev>, David Montague <david@pydantic.dev>, Serge Matveenko <lig@countzero.co>, Marcelo Trylesinski <marcelotryle@gmail.com>, Sydney Runkle <sydneymarierunkle@gmail.com>, David Hewitt <mail@davidhewitt.dev>, Alex Hall <alex.mojaki@gmail.com>, Victorien Plot <contact@vctrn.dev>
# License-Expression: MIT
# Location: d:\Langchain\venv\Lib\site-packages
# Requires: annotated-types, pydantic-core, typing-extensions, typing-inspection
# Required-by: chromadb, fastapi, google-genai, google-generativeai, groq, langchain, langchain-core, langserve, langsmith, openai, pydantic-settings
# ERROR: unknown command "showgoogle-genai"
# Name: langchain
# Version: 0.2.17
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: d:\Langchain\venv\Lib\site-packages
# Requires: aiohttp, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-community
# Name: langchain-google-genai
# Version: 1.0.10
# Summary: An integration package connecting Google's genai package and LangChain
# Home-page: https://github.com/langchain-ai/langchain-google
# Author:
# Author-email:
# License: MIT
# Location: d:\Langchain\venv\Lib\site-packages
# Requires: google-generativeai, langchain-core
# Required-by:

# %%
# !pip show google-genai
# Out:
# Name: google-genai
# Version: 1.21.1
# Summary: GenAI Python SDK
# Home-page: https://github.com/googleapis/python-genai
# Author:
# Author-email: Google LLC <googleapis-packages@google.com>
# License: Apache-2.0
# Location: d:\Langchain\venv\Lib\site-packages
# Requires: anyio, google-auth, httpx, pydantic, requests, tenacity, typing-extensions, websockets
# Required-by:

# %%
# !pip uninstall google-generativeai -y
# Out:
# Found existing installation: google-generativeai 0.7.2
# Uninstalling google-generativeai-0.7.2:
#   Successfully uninstalled google-generativeai-0.7.2

# %%
# !pip install --force-reinstall google-genai==1.21.1
# Out:
# Collecting google-genai==1.21.1
#   Using cached google_genai-1.21.1-py3-none-any.whl.metadata (37 kB)
# Collecting anyio<5.0.0,>=4.8.0 (from google-genai==1.21.1)
#   Downloading anyio-4.14.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-genai==1.21.1)
#   Using cached google_auth-2.55.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting httpx<1.0.0,>=0.28.1 (from google-genai==1.21.1)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3.0.0,>=2.0.0 (from google-genai==1.21.1)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting requests<3.0.0,>=2.28.1 (from google-genai==1.21.1)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting tenacity<9.0.0,>=8.2.3 (from google-genai==1.21.1)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai==1.21.1)
#   Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting typing-extensions<5.0.0,>=4.11.0 (from google-genai==1.21.1)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting idna>=2.8 (from anyio<5.0.0,>=4.8.0->google-genai==1.21.1)
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-genai==1.21.1)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.14.1->google-genai==1.21.1)
#   Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Collecting certifi (from httpx<1.0.0,>=0.28.1->google-genai==1.21.1)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1.0.0,>=0.28.1->google-genai==1.21.1)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai==1.21.1)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->google-genai==1.21.1)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.0.0->google-genai==1.21.1)
#   Using cached pydantic_core-2.46.4-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.0.0->google-genai==1.21.1)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.28.1->google-genai==1.21.1)
#   Using cached charset_normalizer-3.4.7-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting urllib3<3,>=1.26 (from requests<3.0.0,>=2.28.1->google-genai==1.21.1)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-genai==1.21.1)
#   Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-genai==1.21.1)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai==1.21.1)
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Using cached google_genai-1.21.1-py3-none-any.whl (206 kB)
# Downloading anyio-4.14.0-py3-none-any.whl (123 kB)
# Using cached google_auth-2.55.0-py3-none-any.whl (252 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp311-cp311-win_amd64.whl (2.1 MB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.4.7-cp311-cp311-win_amd64.whl (159 kB)
# Using cached idna-3.18-py3-none-any.whl (65 kB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
# Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 328.9 kB/s eta 0:00:10
#    ----- ---------------------------------- 0.5/3.8 MB 328.9 kB/s eta 0:00:10
#    ----- ---------------------------------- 0.5/3.8 MB 328.9 kB/s eta 0:00:10
#    ----- ---------------------------------- 0.5/3.8 MB 328.9 kB/s eta 0:00:10
#    -------- ------------------------------- 0.8/3.8 MB 313.6 kB/s eta 0:00:10
#    -------- ------------------------------- 0.8/3.8 MB 313.6 kB/s eta 0:00:10
#    ----------- ---------------------------- 1.0/3.8 MB 362.1 kB/s eta 0:00:08
#    ----------- ---------------------------- 1.0/3.8 MB 362.1 kB/s eta 0:00:08
#    ----------- ---------------------------- 1.0/3.8 MB 362.1 kB/s eta 0:00:08
#    ----------- ---------------------------- 1.0/3.8 MB 362.1 kB/s eta 0:00:08
#    ----------- ---------------------------- 1.0/3.8 MB 362.1 kB/s eta 0:00:08
#    ------------- -------------------------- 1.3/3.8 MB 321.1 kB/s eta 0:00:08
#    ------------- -------------------------- 1.3/3.8 MB 321.1 kB/s eta 0:00:08
#    ------------- -------------------------- 1.3/3.8 MB 321.1 kB/s eta 0:00:08
#    ------------- -------------------------- 1.3/3.8 MB 321.1 kB/s eta 0:00:08
#    ------------- -------------------------- 1.3/3.8 MB 321.1 kB/s eta 0:00:08
#    ------------- -------------------------- 1.3/3.8 MB 321.1 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 1.6/3.8 MB 292.3 kB/s eta 0:00:08
#    ------------------- -------------------- 1.8/3.8 MB 247.3 kB/s eta 0:00:08
#    ------------------- -------------------- 1.8/3.8 MB 247.3 kB/s eta 0:00:08
#    ------------------- -------------------- 1.8/3.8 MB 247.3 kB/s eta 0:00:08
#    ------------------- -------------------- 1.8/3.8 MB 247.3 kB/s eta 0:00:08
#    ------------------- -------------------- 1.8/3.8 MB 247.3 kB/s eta 0:00:08
#    ---------------------- ----------------- 2.1/3.8 MB 242.1 kB/s eta 0:00:08
#    ---------------------- ----------------- 2.1/3.8 MB 242.1 kB/s eta 0:00:08
#    ---------------------- ----------------- 2.1/3.8 MB 242.1 kB/s eta 0:00:08
#    ---------------------- ----------------- 2.1/3.8 MB 242.1 kB/s eta 0:00:08
#    ---------------------- ----------------- 2.1/3.8 MB 242.1 kB/s eta 0:00:08
#    ---------------------- ----------------- 2.1/3.8 MB 242.1 kB/s eta 0:00:08
#    ------------------------ --------------- 2.4/3.8 MB 241.0 kB/s eta 0:00:07
#    ------------------------ --------------- 2.4/3.8 MB 241.0 kB/s eta 0:00:07
#    ------------------------ --------------- 2.4/3.8 MB 241.0 kB/s eta 0:00:07
#    ------------------------ --------------- 2.4/3.8 MB 241.0 kB/s eta 0:00:07
#    ------------------------ --------------- 2.4/3.8 MB 241.0 kB/s eta 0:00:07
#    --------------------------- ------------ 2.6/3.8 MB 239.7 kB/s eta 0:00:05
#    --------------------------- ------------ 2.6/3.8 MB 239.7 kB/s eta 0:00:05
#    --------------------------- ------------ 2.6/3.8 MB 239.7 kB/s eta 0:00:05
#    --------------------------- ------------ 2.6/3.8 MB 239.7 kB/s eta 0:00:05
#    --------------------------- ------------ 2.6/3.8 MB 239.7 kB/s eta 0:00:05
#    --------------------------- ------------ 2.6/3.8 MB 239.7 kB/s eta 0:00:05
#    ------------------------------ --------- 2.9/3.8 MB 235.0 kB/s eta 0:00:04
#    ------------------------------ --------- 2.9/3.8 MB 235.0 kB/s eta 0:00:04
#    ------------------------------ --------- 2.9/3.8 MB 235.0 kB/s eta 0:00:04
#    ------------------------------ --------- 2.9/3.8 MB 235.0 kB/s eta 0:00:04
#    --------------------------------- ------ 3.1/3.8 MB 240.6 kB/s eta 0:00:03
#    --------------------------------- ------ 3.1/3.8 MB 240.6 kB/s eta 0:00:03
#    --------------------------------- ------ 3.1/3.8 MB 240.6 kB/s eta 0:00:03
#    --------------------------------- ------ 3.1/3.8 MB 240.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 3.4/3.8 MB 246.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 3.4/3.8 MB 246.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 3.4/3.8 MB 246.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 3.4/3.8 MB 246.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 3.4/3.8 MB 246.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 3.4/3.8 MB 246.1 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 242.1 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 242.1 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 242.1 kB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 240.5 kB/s  0:00:15
# Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl (182 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: websockets, urllib3, typing-extensions, tenacity, pycparser, pyasn1, idna, h11, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, pyasn1-modules, httpcore, cffi, anyio, pydantic, httpx, cryptography, google-auth, google-genai
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 15.0.1
#
#     Uninstalling websockets-15.0.1:
#
#       Successfully uninstalled websockets-15.0.1
#
#    ----------------------------------------  0/23 [websockets]
#    ----------------------------------------  0/23 [websockets]
#    ----------------------------------------  0/23 [websockets]
#    ----------------------------------------  0/23 [websockets]
#    ----------------------------------------  0/23 [websockets]
#   Attempting uninstall: urllib3
#    ----------------------------------------  0/23 [websockets]
#     Found existing installation: urllib3 2.7.0
#    ----------------------------------------  0/23 [websockets]
#    - --------------------------------------  1/23 [urllib3]
#     Uninstalling urllib3-2.7.0:
#    - --------------------------------------  1/23 [urllib3]
#       Successfully uninstalled urllib3-2.7.0
#    - --------------------------------------  1/23 [urllib3]
#    - --------------------------------------  1/23 [urllib3]
#    - --------------------------------------  1/23 [urllib3]
#    - --------------------------------------  1/23 [urllib3]
#    - --------------------------------------  1/23 [urllib3]
#    - --------------------------------------  1/23 [urllib3]
#    - --------------------------------------  1/23 [urllib3]
#   Attempting uninstall: typing-extensions
#    - --------------------------------------  1/23 [urllib3]
#     Found existing installation: typing_extensions 4.15.0
#    - --------------------------------------  1/23 [urllib3]
#     Uninstalling typing_extensions-4.15.0:
#    - --------------------------------------  1/23 [urllib3]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    --- ------------------------------------  2/23 [typing-extensions]
#    --- ------------------------------------  2/23 [typing-extensions]
#   Attempting uninstall: tenacity
#    --- ------------------------------------  2/23 [typing-extensions]
#     Found existing installation: tenacity 8.5.0
#    --- ------------------------------------  2/23 [typing-extensions]
#     Uninstalling tenacity-8.5.0:
#    --- ------------------------------------  2/23 [typing-extensions]
#       Successfully uninstalled tenacity-8.5.0
#    --- ------------------------------------  2/23 [typing-extensions]
#    ----- ----------------------------------  3/23 [tenacity]
#    ----- ----------------------------------  3/23 [tenacity]
#   Attempting uninstall: pycparser
#    ----- ----------------------------------  3/23 [tenacity]
#     Found existing installation: pycparser 3.0
#    ----- ----------------------------------  3/23 [tenacity]
#     Uninstalling pycparser-3.0:
#    ----- ----------------------------------  3/23 [tenacity]
#       Successfully uninstalled pycparser-3.0
#    ----- ----------------------------------  3/23 [tenacity]
#    ------ ---------------------------------  4/23 [pycparser]
#    ------ ---------------------------------  4/23 [pycparser]
#   Attempting uninstall: pyasn1
#    ------ ---------------------------------  4/23 [pycparser]
#     Found existing installation: pyasn1 0.6.2
#    ------ ---------------------------------  4/23 [pycparser]
#     Uninstalling pyasn1-0.6.2:
#    ------ ---------------------------------  4/23 [pycparser]
#       Successfully uninstalled pyasn1-0.6.2
#    ------ ---------------------------------  4/23 [pycparser]
#    -------- -------------------------------  5/23 [pyasn1]
#    -------- -------------------------------  5/23 [pyasn1]
#    -------- -------------------------------  5/23 [pyasn1]
#    -------- -------------------------------  5/23 [pyasn1]
#    -------- -------------------------------  5/23 [pyasn1]
#    -------- -------------------------------  5/23 [pyasn1]
#   Attempting uninstall: idna
#    -------- -------------------------------  5/23 [pyasn1]
#     Found existing installation: idna 3.18
#    -------- -------------------------------  5/23 [pyasn1]
#     Uninstalling idna-3.18:
#    -------- -------------------------------  5/23 [pyasn1]
#    ---------- -----------------------------  6/23 [idna]
#       Successfully uninstalled idna-3.18
#    ---------- -----------------------------  6/23 [idna]
#    ---------- -----------------------------  6/23 [idna]
#    ---------- -----------------------------  6/23 [idna]
#   Attempting uninstall: h11
#    ---------- -----------------------------  6/23 [idna]
#     Found existing installation: h11 0.16.0
#    ---------- -----------------------------  6/23 [idna]
#    ------------ ---------------------------  7/23 [h11]
#     Uninstalling h11-0.16.0:
#    ------------ ---------------------------  7/23 [h11]
#       Successfully uninstalled h11-0.16.0
#    ------------ ---------------------------  7/23 [h11]
#    ------------ ---------------------------  7/23 [h11]
#    ------------ ---------------------------  7/23 [h11]
#   Attempting uninstall: charset_normalizer
#    ------------ ---------------------------  7/23 [h11]
#     Found existing installation: charset-normalizer 3.4.7
#    ------------ ---------------------------  7/23 [h11]
#     Uninstalling charset-normalizer-3.4.7:
#    ------------ ---------------------------  7/23 [h11]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
#    ------------- --------------------------  8/23 [charset_normalizer]
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'd:\\langchain\\venv\\lib\\site-packages\\81d243bd2c585b0f4821__mypyc.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
from google import genai
import os

client = genai.Client(
    api_key=os.getenv("GOOGLE_API_KEY")
)

for model in client.models.list():
    print(model.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2416\2484335215.py in ?()
# ----> 1 from google import genai
#       2 import os
#       3
#       4 client = genai.Client(
#
# d:\Langchain\venv\Lib\site-packages\google\genai\__init__.py in ?()
#      15
#      16 """Google Gen AI SDK"""
#      17
#      18 from . import version
# ---> 19 from .client import Client
#      20
#      21
#      22 __version__ = version.__version__
#
# d:\Langchain\venv\Lib\site-packages\google\genai\client.py in ?()
#      18
#      19 import google.auth
#      20 import pydantic
#      21
# ---> 22 from ._api_client import BaseApiClient
#      23 from ._base_url import get_base_url
#      24 from ._replay_api_client import ReplayApiClient
#      25 from .batches import AsyncBatches, Batches
#
# d:\Langchain\venv\Lib\site-packages\google\genai\_api_client.py in ?()
#      53
#      54 from . import _common
#      55 from . import errors
#      56 from . import version
# ---> 57 from .types import HttpOptions
#      58 from .types import HttpOptionsDict
#      59 from .types import HttpOptionsOrDict
#      60 from .types import HttpResponse as SdkHttpResponse
#
# d:\Langchain\venv\Lib\site-packages\google\genai\types.py in ?()
#    3505
#    3506 SpeechConfigUnionDict = Union[SpeechConfigUnion, SpeechConfigDict]
#    3507
#    3508
# -> 3509 class GenerateContentConfig(_common.BaseModel):
#    3510   """Optional model configuration parameters.
#    3511
#    3512   For more information, see `Content generation parameters
#
# d:\Langchain\venv\Lib\site-packages\google\genai\types.py in ?()
#
# AttributeError: module 'pydantic' has no attribute 'field_validator'

# %%
from google import genai
import os

client = genai.Client(
    api_key=os.getenv("GOOGLE_API_KEY")
)

response = client.models.generate_content(
    model="gemini-2.5-pro",
    contents="Hello"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2416\4252358287.py in ?()
# ----> 1 from google import genai
#       2 import os
#       3
#       4 client = genai.Client(
#
# d:\Langchain\venv\Lib\site-packages\google\genai\__init__.py in ?()
#      15
#      16 """Google Gen AI SDK"""
#      17
#      18 from . import version
# ---> 19 from .client import Client
#      20
#      21
#      22 __version__ = version.__version__
#
# d:\Langchain\venv\Lib\site-packages\google\genai\client.py in ?()
#      18
#      19 import google.auth
#      20 import pydantic
#      21
# ---> 22 from ._api_client import BaseApiClient
#      23 from ._base_url import get_base_url
#      24 from ._replay_api_client import ReplayApiClient
#      25 from .batches import AsyncBatches, Batches
#
# d:\Langchain\venv\Lib\site-packages\google\genai\_api_client.py in ?()
#      53
#      54 from . import _common
#      55 from . import errors
#      56 from . import version
# ---> 57 from .types import HttpOptions
#      58 from .types import HttpOptionsDict
#      59 from .types import HttpOptionsOrDict
#      60 from .types import HttpResponse as SdkHttpResponse
#
# d:\Langchain\venv\Lib\site-packages\google\genai\types.py in ?()
#    3505
#    3506 SpeechConfigUnionDict = Union[SpeechConfigUnion, SpeechConfigDict]
#    3507
#    3508
# -> 3509 class GenerateContentConfig(_common.BaseModel):
#    3510   """Optional model configuration parameters.
#    3511
#    3512   For more information, see `Content generation parameters
#
# d:\Langchain\venv\Lib\site-packages\google\genai\types.py in ?()
#
# AttributeError: module 'pydantic' has no attribute 'field_validator'
