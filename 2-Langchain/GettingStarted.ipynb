# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-flash",
    temperature=0.5
)
print(llm)
# Out:
# output_version=None profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-03-20', 'last_updated': '2025-06-05', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True} google_api_key=SecretStr('**********') location=None model='models/gemini-2.5-flash' temperature=0.5 client=<google.genai.client.Client object at 0x000001CD56C33450> default_metadata=() model_kwargs={}

# %%
result=llm.invoke("Explain Bayes Theorem in detail")

# %%
print(result)
# Out:
# content='Bayes\' Theorem is a fundamental concept in probability theory and statistics that describes how to update the probability of a hypothesis based on new evidence. It\'s a powerful tool for rational inference and is at the heart of Bayesian statistics.\n\nLet\'s break it down in detail.\n\n---\n\n### The Core Idea: Updating Beliefs with Evidence\n\nImagine you have an initial belief about something (a "hypothesis"). Then, you observe some new data or evidence. Bayes\' Theorem provides a mathematical way to calculate how your initial belief should change in light of this new evidence.\n\nIt essentially allows us to reverse conditional probabilities: if we know the probability of evidence given a hypothesis, Bayes\' Theorem helps us find the probability of the hypothesis given the evidence.\n\n---\n\n### The Formula\n\nBayes\' Theorem is typically expressed as:\n\n$$P(H|E) = \\frac{P(E|H) \\cdot P(H)}{P(E)}$$\n\nWhere:\n\n*   **$P(H|E)$ (Posterior Probability):** This is what we want to find. It\'s the probability of the **Hypothesis (H)** being true *given* the **Evidence (E)** has been observed. It represents our *updated* belief after seeing the evidence.\n*   **$P(E|H)$ (Likelihood):** This is the probability of observing the **Evidence (E)** *if* the **Hypothesis (H)** is true. It measures how well the evidence supports the hypothesis.\n*   **$P(H)$ (Prior Probability):** This is the initial probability of the **Hypothesis (H)** being true *before* we observe any evidence. It represents our initial belief or knowledge.\n*   **$P(E)$ (Marginal Likelihood / Evidence Probability):** This is the overall probability of observing the **Evidence (E)**, regardless of whether the hypothesis is true or not. It acts as a normalizing constant to ensure that $P(H|E)$ is a valid probability (i.e., between 0 and 1).\n\n---\n\n### Breaking Down Each Component\n\n1.  **Prior Probability ($P(H)$): Your Initial Belief**\n    *   This is your starting point. It\'s the probability you assign to your hypothesis *before* considering any new evidence.\n    *   **Example:** If you\'re trying to determine if a person has a rare disease, $P(H)$ would be the general prevalence of that disease in the population. If you\'re trying to guess if a coin is biased, $P(H)$ might be your initial belief that it\'s a fair coin (e.g., 0.99) or a biased coin (e.g., 0.01).\n    *   **Nature:** Priors can be objective (based on historical data, known frequencies) or subjective (based on expert opinion, personal experience, or even an educated guess when objective data is scarce). The choice of prior is a key aspect of Bayesian analysis.\n\n2.  **Likelihood ($P(E|H)$): How Well the Evidence Fits the Hypothesis**\n    *   This is the probability of observing the specific evidence *if* your hypothesis is true. It\'s a measure of how compatible the evidence is with your hypothesis.\n    *   **Example:** If the hypothesis ($H$) is "the person has the disease," and the evidence ($E$) is "the test result is positive," then $P(E|H)$ is the sensitivity of the test – the probability of testing positive *given* that the person actually has the disease.\n    *   **Crucial Distinction:** $P(E|H)$ is NOT the same as $P(H|E)$. This is a common point of confusion. $P(E|H)$ is about the evidence given the hypothesis, while $P(H|E)$ is about the hypothesis given the evidence.\n\n3.  **Marginal Likelihood / Evidence Probability ($P(E)$): The Overall Probability of the Evidence**\n    *   This term can be the trickiest. It\'s the probability of observing the evidence *E* under *all possible hypotheses*.\n    *   It acts as a normalizing constant. Without it, the numerator $P(E|H) \\cdot P(H)$ would give you a value proportional to $P(H|E)$, but not necessarily a valid probability.\n    *   **Calculation:** For a simple case with two mutually exclusive and exhaustive hypotheses ($H$ and $\\neg H$, meaning "not H"), $P(E)$ is calculated using the Law of Total Probability:\n        ...

# %%
import os
from google import genai

client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

for m in client.models.list():
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
# models/gemini-3.5-live-translate-preview

# %%
### chatPrompt Template
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answer based on the question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answer based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt|llm
response=chain.invoke({"input":"Can you tell me who is Rohit Sharma?"})
print(response)
# Out:
# content='Rohit Sharma is a highly acclaimed **Indian international cricketer** who is widely regarded as one of the greatest white-ball cricketers of all time.\n\nHere\'s a breakdown of who he is:\n\n1.  **Role:** He is a **right-handed opening batsman** and a former captain of the Indian national cricket team across all formats (Test, One Day International, and Twenty20 International).\n2.  **Nickname:** He is famously known as **"Hitman"** due to his ability to score big hundreds and hit sixes with remarkable ease, especially once he gets set.\n3.  **Playing Style:** Rohit is celebrated for his **elegant, free-flowing batting style**, exceptional timing, and the ability to convert starts into massive scores, particularly in limited-overs cricket.\n4.  **Key Records & Achievements:**\n    *   He holds the unique record of being the **only batsman to score three double centuries in One Day Internationals (ODIs)**.\n    *   He holds the record for the **most centuries in T20 Internationals**.\n    *   He was the **highest run-scorer in the 2019 Cricket World Cup**.\n    *   One of the most prolific run-scorers in white-ball cricket history.\n5.  **Captaincy:**\n    *   He has captained India in all three formats, leading them to various bilateral series victories.\n    *   He is also one of the most successful captains in the **Indian Premier League (IPL)**, having led the **Mumbai Indians** to a record **five IPL titles**.\n6.  **Overall Impact:** His calm demeanor on the field, combined with his explosive and stylish batting, has made him a global cricketing icon and a fan favorite.\n\nIn essence, Rohit Sharma is a cricketing legend whose records, captaincy, and elegant yet destructive batting have left an indelible mark on the sport.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019ec42f-2090-78b0-a2b1-8147765342de-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 24, 'output_tokens': 1691, 'total_tokens': 1715, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1288}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser
response=chain.invoke({"input":"who is Vedant Shelake"})
print(response)
# Out:
# Vedant Shelake is a notable individual primarily recognized for his work and contributions in the field of **technology, particularly in software engineering, machine learning, and artificial intelligence.**
#
# Based on his public profiles (like LinkedIn and GitHub), he is often identified as:
#
# 1.  **A Software Engineer/Machine Learning Engineer:** He has experience and skills in developing software applications, working with data, and implementing machine learning models.
# 2.  **An AI/ML Enthusiast and Developer:** He actively engages in projects, research, and development related to artificial intelligence and machine learning, often showcasing his work on platforms like GitHub.
# 3.  **A Student/Graduate from a Technical University:** Many of his profiles indicate a background in Computer Science or a related engineering discipline from a reputable institution.
# 4.  **Active in Tech Communities:** He often participates in hackathons, contributes to open-source projects, and shares his knowledge and projects online.
#
# His skill set typically includes programming languages like Python, and expertise in areas such as Deep Learning, Data Science, Web Development, and various AI/ML frameworks.
#
# While there might be other individuals with the same name, the most prominent online presence for "Vedant Shelake" typically points to this profile within the tech and engineering community.
