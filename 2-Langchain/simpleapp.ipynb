# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
##Data Ingestion --From the website we need to scrape the data
from langchain_community.document_loaders import WebBaseLoader

# %%
loader=WebBaseLoader("https://docs.smith.langchain.com/tutorials/Administrators/manage_spend")
loader

# %%
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://docs.smith.langchain.com/tutorials/Administrators/manage_spend', 'title': 'LangSmith overview - Docs by LangChain', 'language': 'en'}, page_content='LangSmith overview - Docs by LangChainDocumentation IndexFetch the complete documentation index at: /llms.txtUse this file to discover all available pages before exploring further.Skip to main contentDocs by LangChain home pageHomeSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith overviewHomeLangSmithAgent lifecycleLangSmith overviewCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance. Meet with our team to learn more or visit our Trust Center.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.\n\n\n\nConnect these docs to Claude, VSCode, and more via MCP for real-time answers.Edit this page on GitHub or file an issue.Was this page helpful?YesNoPreviousAgent lifecycleNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyContact SalesCompanyHomeTrust CenterCareersBloggithubxlinkedinyoutube\n')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
doucuments=text_splitter.split_documents(docs)

# %%
doucuments
# Out:
# [Document(metadata={'source': 'https://docs.smith.langchain.com/tutorials/Administrators/manage_spend', 'title': 'LangSmith overview - Docs by LangChain', 'language': 'en'}, page_content='LangSmith overview - Docs by LangChainDocumentation IndexFetch the complete documentation index at: /llms.txtUse this file to discover all available pages before exploring further.Skip to main contentDocs by LangChain home pageHomeSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith overviewHomeLangSmithAgent lifecycleLangSmith overviewCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.'),
#  Document(metadata={'source': 'https://docs.smith.langchain.com/tutorials/Administrators/manage_spend', 'title': 'LangSmith overview - Docs by LangChain', 'language': 'en'}, page_content='Copy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build'),
#  Document(metadata={'source': 'https://docs.smith.langchain.com/tutorials/Administrators/manage_spend', 'title': 'LangSmith overview - Docs by LangChain', 'language': 'en'}, page_content='\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance. Meet with our team to learn more or visit our Trust Center.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'),
#  Document(metadata={'source': 'https://docs.smith.langchain.com/tutorials/Administrators/manage_spend', 'title': 'LangSmith overview - Docs by LangChain', 'language': 'en'}, page_content='Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Edit this page on GitHub or file an issue.Was this page helpful?YesNoPreviousAgent lifecycleNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyContact SalesCompanyHomeTrust CenterCareersBloggithubxlinkedinyoutube')]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
embeddings=GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

# %%
from langchain_community.vectorstores import FAISS
vectorstoredb=FAISS.from_documents(doucuments,embeddings)
vectorstoredb

# %%
query="LangSmith has two usage limits: total traces and extended"
result=vectorstoredb.similarity_search(query)

# %%
result[0].page_content
# Out:
# '\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance. Meet with our team to learn more or visit our Trust Center.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-flash",
    temperature=0.5
)

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

print("Success")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 from langchain.chains.combine_documents import create_stuff_documents_chain
#       3 print("Success")
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\combine_documents\__init__.py:3
#       1 """Different ways to combine documents."""
# ----> 3 from langchain.chains.combine_documents.reduce import (
#       4     acollapse_docs,
#       5     collapse_docs,
#       6     split_list_of_docs,
#       7 )
#       8 from langchain.chains.combine_documents.stuff import create_stuff_documents_chain
#      10 __all__ = [
#      11     "acollapse_docs",
#      12     "collapse_docs",
#      13     "split_list_of_docs",
#      14     "create_stuff_documents_chain",
#      15 ]
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\combine_documents\reduce.py:10
#       7 from langchain_core.callbacks import Callbacks
#       8 from langchain_core.documents import Document
# ---> 10 from langchain.chains.combine_documents.base import BaseCombineDocumentsChain
#      13 class CombineDocsProtocol(Protocol):
#      14     """Interface for the combine_docs method."""
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\combine_documents\base.py:18
#      15 from langchain_core.runnables.utils import create_model
#      16 from langchain_text_splitters import RecursiveCharacterTextSplitter, TextSplitter
# ---> 18 from langchain.chains.base import Chain
#      20 DEFAULT_DOCUMENT_SEPARATOR = "\n\n"
#      21 DOCUMENTS_KEY = "context"
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\base.py:32
#      24 from langchain_core.runnables import (
#      25     RunnableConfig,
#      26     RunnableSerializable,
#      27     ensure_config,
#      28     run_in_executor,
#      29 )
#      30 from langchain_core.runnables.utils import create_model
# ---> 32 from langchain.schema import RUN_KEY
#      34 logger = logging.getLogger(__name__)
#      37 def _get_verbosity() -> bool:
#
# File d:\Langchain\venv\Lib\site-packages\langchain\schema\__init__.py:5
#       3 from langchain_core.agents import AgentAction, AgentFinish
#       4 from langchain_core.caches import BaseCache
# ----> 5 from langchain_core.chat_history import BaseChatMessageHistory
#       6 from langchain_core.documents import BaseDocumentTransformer, Document
#       7 from langchain_core.exceptions import LangChainException, OutputParserException
#
# File d:\Langchain\venv\Lib\site-packages\langchain_core\chat_history.py:200
#     196         """Return a string representation of the chat history."""
#     197         return get_buffer_string(self.messages)
# --> 200 class InMemoryChatMessageHistory(BaseChatMessageHistory, BaseModel):
#     201     """In memory implementation of chat message history.
#     202
#     203     Stores messages in a memory list.
#     204     """
#     206     messages: List[BaseMessage] = Field(default_factory=list)
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\main.py:214, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     206     if (
#     207         is_untouched(value)
#     208         and ann_type != PyObject
#    (...)    211         )
#     212     ):
#     213         continue
# --> 214     fields[ann_name] = ModelField.infer(
#     215         name=ann_name,
#     216         value=value,
#     217         annotation=ann_type,
#     218         class_validators=vg.get_validators(ann_name),
#     219         config=config,
#     220     )
#     221 elif ann_name not in namespace and config.underscore_attrs_are_private:
#     222     private_attributes[ann_name] = PrivateAttr()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:504, in ModelField.infer(cls, name, value, annotation, class_validators, config)
#     501     required = False
#     502 annotation = get_annotation_from_field_info(annotation, field_info, name, config.validate_assignment)
# --> 504 return cls(
#     505     name=name,
#     506     type_=annotation,
#     507     alias=field_info.alias,
#     508     class_validators=class_validators,
#     509     default=value,
#     510     default_factory=field_info.default_factory,
#     511     required=required,
#     512     model_config=config,
#     513     field_info=field_info,
#     514 )
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:434, in ModelField.__init__(self, name, type_, class_validators, model_config, default, default_factory, required, final, alias, field_info)
#     432 self.shape: int = SHAPE_SINGLETON
#     433 self.model_config.prepare_field(self)
# --> 434 self.prepare()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:550, in ModelField.prepare(self)
#     545 if self.type_.__class__ is ForwardRef or self.type_.__class__ is DeferredType:
#     546     # self.type_ is currently a ForwardRef and there's nothing we can do now,
#     547     # user will need to call model.update_forward_refs()
#     548     return
# --> 550 self._type_analysis()
#     551 if self.required is Undefined:
#     552     self.required = True
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:756, in ModelField._type_analysis(self)
#     753     raise TypeError(f'Fields of type "{origin}" are not supported.')
#     755 # type_ has been refined eg. as the type of a List and sub_fields needs to be populated
# --> 756 self.sub_fields = [self._create_sub_type(self.type_, '_' + self.name)]
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:806, in ModelField._create_sub_type(self, type_, name, for_keys)
#     791     class_validators = {
#     792         k: Validator(
#     793             func=v.func,
#    (...)    801         if v.each_item
#     802     }
#     804 field_info, _ = self._get_field_info(name, type_, None, self.model_config)
# --> 806 return self.__class__(
#     807     type_=type_,
#     808     name=name,
#     809     class_validators=class_validators,
#     810     model_config=self.model_config,
#     811     field_info=field_info,
#     812 )
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:434, in ModelField.__init__(self, name, type_, class_validators, model_config, default, default_factory, required, final, alias, field_info)
#     432 self.shape: int = SHAPE_SINGLETON
#     433 self.model_config.prepare_field(self)
# --> 434 self.prepare()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:555, in ModelField.prepare(self)
#     553 if self.default is Undefined and self.default_factory is None:
#     554     self.default = None
# --> 555 self.populate_validators()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:829, in ModelField.populate_validators(self)
#     825 if not self.sub_fields or self.shape == SHAPE_GENERIC:
#     826     get_validators = getattr(self.type_, '__get_validators__', None)
#     827     v_funcs = (
#     828         *[v.func for v in class_validators_ if v.each_item and v.pre],
# --> 829         *(get_validators() if get_validators else list(find_validators(self.type_, self.model_config))),
#     830         *[v.func for v in class_validators_ if v.each_item and not v.pre],
#     831     )
#     832     self.validators = prep_validators(v_funcs)
#     834 self.pre_validators = []
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\validators.py:768, in find_validators(type_, config)
#     766 if hasattr(type_, '__pydantic_core_schema__'):
#     767     warn(f'Mixing V1 and V2 models is not supported. `{type_.__name__}` is a V2 model.', UserWarning)
# --> 768 raise RuntimeError(f'no validator found for {type_}, see `arbitrary_types_allowed` in Config')
#
# RuntimeError: no validator found for <class 'langchain_core.messages.base.BaseMessage'>, see `arbitrary_types_allowed` in Config

# %%
## Retrival chain ,Document chain

from langchain.chains.combine_documents import create_stuff_documents_chain
# from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_template(
    """
Answer the following question based only on the provided context:
<context>
{context}
</context>


"""
)

document_chain=create_stuff_documents_chain(llm,prompt)
document_chain
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[53], line 3
#       1 ## Retrival chain ,Document chain
# ----> 3 from langchain.chains.combine_documents import create_stuff_documents_chain
#       4 # from langchain.chains import create_retrieval_chain
#       5 from langchain_core.prompts import ChatPromptTemplate
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\combine_documents\__init__.py:3
#       1 """Different ways to combine documents."""
# ----> 3 from langchain.chains.combine_documents.reduce import (
#       4     acollapse_docs,
#       5     collapse_docs,
#       6     split_list_of_docs,
#       7 )
#       8 from langchain.chains.combine_documents.stuff import create_stuff_documents_chain
#      10 __all__ = [
#      11     "acollapse_docs",
#      12     "collapse_docs",
#      13     "split_list_of_docs",
#      14     "create_stuff_documents_chain",
#      15 ]
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\combine_documents\reduce.py:10
#       7 from langchain_core.callbacks import Callbacks
#       8 from langchain_core.documents import Document
# ---> 10 from langchain.chains.combine_documents.base import BaseCombineDocumentsChain
#      13 class CombineDocsProtocol(Protocol):
#      14     """Interface for the combine_docs method."""
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\combine_documents\base.py:18
#      15 from langchain_core.runnables.utils import create_model
#      16 from langchain_text_splitters import RecursiveCharacterTextSplitter, TextSplitter
# ---> 18 from langchain.chains.base import Chain
#      20 DEFAULT_DOCUMENT_SEPARATOR = "\n\n"
#      21 DOCUMENTS_KEY = "context"
#
# File d:\Langchain\venv\Lib\site-packages\langchain\chains\base.py:32
#      24 from langchain_core.runnables import (
#      25     RunnableConfig,
#      26     RunnableSerializable,
#      27     ensure_config,
#      28     run_in_executor,
#      29 )
#      30 from langchain_core.runnables.utils import create_model
# ---> 32 from langchain.schema import RUN_KEY
#      34 logger = logging.getLogger(__name__)
#      37 def _get_verbosity() -> bool:
#
# File d:\Langchain\venv\Lib\site-packages\langchain\schema\__init__.py:5
#       3 from langchain_core.agents import AgentAction, AgentFinish
#       4 from langchain_core.caches import BaseCache
# ----> 5 from langchain_core.chat_history import BaseChatMessageHistory
#       6 from langchain_core.documents import BaseDocumentTransformer, Document
#       7 from langchain_core.exceptions import LangChainException, OutputParserException
#
# File d:\Langchain\venv\Lib\site-packages\langchain_core\chat_history.py:200
#     196         """Return a string representation of the chat history."""
#     197         return get_buffer_string(self.messages)
# --> 200 class InMemoryChatMessageHistory(BaseChatMessageHistory, BaseModel):
#     201     """In memory implementation of chat message history.
#     202
#     203     Stores messages in a memory list.
#     204     """
#     206     messages: List[BaseMessage] = Field(default_factory=list)
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\main.py:214, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     206     if (
#     207         is_untouched(value)
#     208         and ann_type != PyObject
#    (...)    211         )
#     212     ):
#     213         continue
# --> 214     fields[ann_name] = ModelField.infer(
#     215         name=ann_name,
#     216         value=value,
#     217         annotation=ann_type,
#     218         class_validators=vg.get_validators(ann_name),
#     219         config=config,
#     220     )
#     221 elif ann_name not in namespace and config.underscore_attrs_are_private:
#     222     private_attributes[ann_name] = PrivateAttr()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:504, in ModelField.infer(cls, name, value, annotation, class_validators, config)
#     501     required = False
#     502 annotation = get_annotation_from_field_info(annotation, field_info, name, config.validate_assignment)
# --> 504 return cls(
#     505     name=name,
#     506     type_=annotation,
#     507     alias=field_info.alias,
#     508     class_validators=class_validators,
#     509     default=value,
#     510     default_factory=field_info.default_factory,
#     511     required=required,
#     512     model_config=config,
#     513     field_info=field_info,
#     514 )
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:434, in ModelField.__init__(self, name, type_, class_validators, model_config, default, default_factory, required, final, alias, field_info)
#     432 self.shape: int = SHAPE_SINGLETON
#     433 self.model_config.prepare_field(self)
# --> 434 self.prepare()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:550, in ModelField.prepare(self)
#     545 if self.type_.__class__ is ForwardRef or self.type_.__class__ is DeferredType:
#     546     # self.type_ is currently a ForwardRef and there's nothing we can do now,
#     547     # user will need to call model.update_forward_refs()
#     548     return
# --> 550 self._type_analysis()
#     551 if self.required is Undefined:
#     552     self.required = True
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:756, in ModelField._type_analysis(self)
#     753     raise TypeError(f'Fields of type "{origin}" are not supported.')
#     755 # type_ has been refined eg. as the type of a List and sub_fields needs to be populated
# --> 756 self.sub_fields = [self._create_sub_type(self.type_, '_' + self.name)]
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:806, in ModelField._create_sub_type(self, type_, name, for_keys)
#     791     class_validators = {
#     792         k: Validator(
#     793             func=v.func,
#    (...)    801         if v.each_item
#     802     }
#     804 field_info, _ = self._get_field_info(name, type_, None, self.model_config)
# --> 806 return self.__class__(
#     807     type_=type_,
#     808     name=name,
#     809     class_validators=class_validators,
#     810     model_config=self.model_config,
#     811     field_info=field_info,
#     812 )
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:434, in ModelField.__init__(self, name, type_, class_validators, model_config, default, default_factory, required, final, alias, field_info)
#     432 self.shape: int = SHAPE_SINGLETON
#     433 self.model_config.prepare_field(self)
# --> 434 self.prepare()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:555, in ModelField.prepare(self)
#     553 if self.default is Undefined and self.default_factory is None:
#     554     self.default = None
# --> 555 self.populate_validators()
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\fields.py:829, in ModelField.populate_validators(self)
#     825 if not self.sub_fields or self.shape == SHAPE_GENERIC:
#     826     get_validators = getattr(self.type_, '__get_validators__', None)
#     827     v_funcs = (
#     828         *[v.func for v in class_validators_ if v.each_item and v.pre],
# --> 829         *(get_validators() if get_validators else list(find_validators(self.type_, self.model_config))),
#     830         *[v.func for v in class_validators_ if v.each_item and not v.pre],
#     831     )
#     832     self.validators = prep_validators(v_funcs)
#     834 self.pre_validators = []
#
# File d:\Langchain\venv\Lib\site-packages\pydantic\v1\validators.py:768, in find_validators(type_, config)
#     766 if hasattr(type_, '__pydantic_core_schema__'):
#     767     warn(f'Mixing V1 and V2 models is not supported. `{type_.__name__}` is a V2 model.', UserWarning)
# --> 768 raise RuntimeError(f'no validator found for {type_}, see `arbitrary_types_allowed` in Config')
#
# RuntimeError: no validator found for <class 'langchain_core.messages.base.BaseMessage'>, see `arbitrary_types_allowed` in Config

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.1
